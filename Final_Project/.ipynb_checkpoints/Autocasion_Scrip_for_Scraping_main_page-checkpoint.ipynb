# %% [markdown]
# # Autocasion Scrip for Scraping main page

# %% [markdown]
# Source: https://www.autocasion.com

# %%
The script contains a filter in the webpage price 4000 to 16000 and year starting from 2014

# %%
import pandas as pd
import time
import re
import requests
from bs4 import BeautifulSoup
import random
import numpy as np

# %%
headers= {'Accept-Encoding':'gzip, deflate',
          'Accept-Language':'en-US,en;q=0.9',
          'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.88 Safari/537.36'}

# %%
"""main_list = []
maindf2 = pd.DataFrame()
count=0
#from page 1 to 625, after 625 there are no more cars
for page in range(1,1):
    print(page)
    url = 'https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page='+str(page)
    time.sleep(random.randint(0,5))
    try:
        #Validate response and get the soup
        headers= {'Accept-Encoding':'gzip, deflate',
          'Accept-Language':'en-US,en;q=0.9',
          'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.88 Safari/537.36'}
        response = requests.get(url ,headers=headers)
        soup = BeautifulSoup(response.content)
        #print(soup)
        vehiculos = soup.find_all('article',{'class':'anuncio evaluacion'})
        models_listA = []
        for element in range(len(vehiculos)):
            temp_list = []
            model =vehiculos[element].a.h2.text #Description
            price =vehiculos[element].a.find_all('p',{'class':'precio'})[0].find_all('span')[0].text
            sub_location = vehiculos[element].ul.find_all('li')[0].span.text # Provincia
            year =vehiculos[element].ul.find_all('li')[1].span.text # Matriculación
            fuel = vehiculos[element].ul.find_all('li')[2].span.text # Combustible
            kilom =vehiculos[element].ul.find_all('li')[3].span.text # Kilómetros
            manual_auto = vehiculos[element].ul.find_all('li')[4].span.text # Cambio
            power = vehiculos[element].ul.find_all('li')[5].span.text # Potencia
            link = vehiculos[element].a['href'] #link

            temp_list.append(model)
            temp_list.append(price)
            temp_list.append(sub_location)
            temp_list.append(year)
            temp_list.append(fuel)
            temp_list.append(kilom)
            temp_list.append(manual_auto)
            temp_list.append(link)
            models_listA.append(temp_list)
            print(models_listA)
            

        #TypeB
        vehiculos = soup.find_all('article',{'class':'anuncio destacado evaluacion'}) 
        models_listB = []
        for element in range(len(vehiculos)):
            temp_list = []
            model =vehiculos[element].a.h2.text #Description
            price =vehiculos[element].a.find_all('p',{'class':'precio'})[0].find_all('span')[0].text
            sub_location = vehiculos[element].ul.find_all('li')[0].span.text # Provincia
            year =vehiculos[element].ul.find_all('li')[1].span.text # Matriculación
            fuel = vehiculos[element].ul.find_all('li')[2].span.text # Combustible
            kilom =vehiculos[element].ul.find_all('li')[3].span.text # Kilómetros
            manual_auto = vehiculos[element].ul.find_all('li')[4].span.text # Cambio
            power = vehiculos[element].ul.find_all('li')[5].span.text # Potencia
            link = vehiculos[element].a['href'] #link

            temp_list.append(model)
            temp_list.append(price)
            temp_list.append(sub_location)
            temp_list.append(year)
            temp_list.append(fuel)
            temp_list.append(kilom)
            temp_list.append(manual_auto)
            temp_list.append(link)
            models_listB.append(temp_list)
            print(models_listB)
        #TypeC
        vehiculos = soup.find_all('article',{'class':'anuncio destacado'}) 
        models_listC = []
        for element in range(len(vehiculos)):
            temp_list = []
            model =vehiculos[element].a.h2.text #Description
            price =vehiculos[element].a.find_all('p',{'class':'precio'})[0].find_all('span')[0].text
            sub_location = vehiculos[element].ul.find_all('li')[0].span.text # Provincia
            year =vehiculos[element].ul.find_all('li')[1].span.text # Matriculación
            fuel = vehiculos[element].ul.find_all('li')[2].span.text # Combustible
            kilom =vehiculos[element].ul.find_all('li')[3].span.text # Kilómetros
            manual_auto = vehiculos[element].ul.find_all('li')[4].span.text # Cambio
            power = vehiculos[element].ul.find_all('li')[5].span.text # Potencia
            link = vehiculos[element].a['href'] #link

            temp_list.append(model)
            temp_list.append(price)
            temp_list.append(sub_location)
            temp_list.append(year)
            temp_list.append(fuel)
            temp_list.append(kilom)
            temp_list.append(manual_auto)
            temp_list.append(link)
            models_listC.append(temp_list)
            print(models_listC)
            
        #TypeD
        vehiculos = soup.find_all('article',{'class':'anuncio'}) 
        models_listD = []
        for element in range(len(vehiculos)):
            temp_list = []
            model =vehiculos[element].a.h2.text #Description
            price =vehiculos[element].a.find_all('p',{'class':'precio'})[0].find_all('span')[0].text
            sub_location = vehiculos[element].ul.find_all('li')[0].span.text # Provincia
            year =vehiculos[element].ul.find_all('li')[1].span.text # Matriculación
            fuel = vehiculos[element].ul.find_all('li')[2].span.text # Combustible
            kilom =vehiculos[element].ul.find_all('li')[3].span.text # Kilómetros
            manual_auto = vehiculos[element].ul.find_all('li')[4].span.text # Cambio
            power = vehiculos[element].ul.find_all('li')[5].span.text # Potencia
            link = vehiculos[element].a['href'] #link

            temp_list.append(model)
            temp_list.append(price)
            temp_list.append(sub_location)
            temp_list.append(year)
            temp_list.append(fuel)
            temp_list.append(kilom)
            temp_list.append(manual_auto)
            temp_list.append(link)
            models_listD.append(temp_list)    
            print(models_listD)

        main_list.append(models_listA+models_listB+models_listC+models_listD)
        dfprov = pd.DataFrame(main_list)
        maindf2 = concat([maindf2,dfprov])
        #num = np.random.randint(1,10000000)
        #maindf.to_csv(f'autocasion_page{num}.csv')
        count = count+1

    except:
            pass
print(page)        
maindf = pd.DataFrame()
#num = np.random.randint(1,10000000)
for element in main_list:
    dfprov = pd.DataFrame(element)
    maindf = maindf.append(dfprov)
    #maindf.to_csv(f'autocasion_page{num}.csv')
maindf.to_csv('autocasion_unique.csv')"""
# Out:
# 1

# %%
"""maindf"""
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
""" #TypeD
vehiculos = soup.find_all('article',{'class':'anuncio'}) 
models_listC = []"""
"""        for element in range(len(vehiculos)):
            temp_list = []
            model =vehiculos[element].a.h2.text #Description
            price =vehiculos[element].a.find_all('p',{'class':'precio'})[0].find_all('span')[0].text
            sub_location = vehiculos[element].ul.find_all('li')[0].span.text # Provincia
            year =vehiculos[element].ul.find_all('li')[1].span.text # Matriculación
            fuel = vehiculos[element].ul.find_all('li')[2].span.text # Combustible
            kilom =vehiculos[element].ul.find_all('li')[3].span.text # Kilómetros
            manual_auto = vehiculos[element].ul.find_all('li')[4].span.text # Cambio
            power = vehiculos[element].ul.find_all('li')[5].span.text # Potencia
            link = vehiculos[element].a['href'] #link
"""
# Out:
# "        for element in range(len(vehiculos)):\n           temp_list = []\n           model =vehiculos[element].a.h2.text #Description\n           price =vehiculos[element].a.find_all('p',{'class':'precio'})[0].find_all('span')[0].text\n           sub_location = vehiculos[element].ul.find_all('li')[0].span.text # Provincia\n           year =vehiculos[element].ul.find_all('li')[1].span.text # Matriculación\n           fuel = vehiculos[element].ul.find_all('li')[2].span.text # Combustible\n           kilom =vehiculos[element].ul.find_all('li')[3].span.text # Kilómetros\n           manual_auto = vehiculos[element].ul.find_all('li')[4].span.text # Cambio\n           power = vehiculos[element].ul.find_all('li')[5].span.text # Potencia\n           link = vehiculos[element].a['href'] #link\n"

# %%
"""vehiculos[0]"""
# Out:
# <article class="anuncio evaluacion" data-ng-mouseenter="overTextLinkPubli($event)" data-ng-mouseleave="leaveTextLinkPubli($event)">
# <a href="/coches-segunda-mano/citroen-c1-ocasion/c1-1-0-vti-city-edition-72-ref7030504">
# <div class="img-anuncio">
# <img alt="CITROEN C1 1.0 VTi City Edition 72" class="type-image" itemprop="image" lazyload="" src="//images0.autocasion.com/unsafe/273x176/filters:fill(white):quality(80)/ad/05/2177/4c548b4edb69baaa845171f091fbe809d1cac2b0.jpeg" title=""/>
# <p class="fotos"><span class="icon icon-camara"></span>11</p>
# </div>
# <div class="contenido-anuncio">
# <h2 itemprop="name">  CITROEN C1 1.0 VTi City Edition 72  </h2>
# <p class="precio">
# <span>11.795 € </span>
# <span>Precio al contado</span>
# </p>
# <p class="precio financiado">
# <span>10.045 € </span>
# <span>Precio financiado</span>
# </p>
# <ul>
# <li>Provincia: <span>Valladolid</span></li>
# <li>Matriculación: <span>2020</span></li>
# <li>Combustible: <span> Gasolina</span></li>
# <li>Kilómetros: <span>11.007 km</span></li>
# <li>Cambio: <span>Manual</span></li>
# <li>Potencia: <span>72 cv</span></li>
# </ul>
# </div>
# <div class="valoracion">
# <span>Valoración del concesionario</span>
# <p class="titulo">PALAUSA VALLADOLID VOLVO y  CITROEN en Valladolid</p>
# <p><span>4,0</span>/5</p>
# <div class="rateit" data-rateit-readonly="true" data-rateit-starheight="15" data-rateit-starwidth="15" data-rateit-value="4" title="Puntuación promedio: 4">
# </div>
# </div>
# </a>
# <div class="otros-enlaces">
# <a class="ng-non-bindable textlink-publi" data-hash="2c729e72aabf710ae5025b0e012c242c" href="https://pubads.g.doubleclick.net/gampad/clk?id=215487363&amp;iu=/4900/vocento.autocasion/text-link&amp;16592682021" rel="nofollow" target="_blank">Calcula tu seguro</a>
# <ng-contact-modal class="" data-ad="7030504" data-icon="icon icon-mail-telefono" data-is-mobile="" data-is-tablet="" data-label="Contactar" data-list="" data-ng-cloak="" data-origin="3" data-scope="parrilla" data-utm-source=""><!-- CONTACT BUTTON IS NOT ALIVEEEE --></ng-contact-modal>
# <a class="favoritos icon icon-estrella-masa" data-ad="7030504" data-ng-favorite="" data-user="false" href="#" role="button" title="Favoritos"></a>
# <a class="comparador icon icon-comparador" data-ad="7030504" data-classname="AdUsedCar" data-km0="" data-ng-class="comparatorStatus(7030504)" href="" ng-click="clickAdToComparator($event)" title="Comparador"></a>
# </div>
# </article>

# %% [markdown]
# # MAIN

# %%
main_list = []
count=0
#complete from 1 to 800
for page in range(1,626):
    url = 'https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page='+str(page)
    print(url)
    time.sleep(random.randint(0,5))
    try:
        #Validate response and get the soup
        response = requests.get(url ,headers=headers)
        soup = BeautifulSoup(response.content)
        #print(soup)
        vehiculos = soup.find_all('article',{'class':'anuncio evaluacion'})
        models_listA = []
        for element in range(len(vehiculos)):
            temp_list = []
            model =vehiculos[element].a.h2.text #Description
            price =vehiculos[element].a.find_all('p',{'class':'precio'})[0].find_all('span')[0].text
            sub_location = vehiculos[element].ul.find_all('li')[0].span.text # Provincia
            year =vehiculos[element].ul.find_all('li')[1].span.text # Matriculación
            fuel = vehiculos[element].ul.find_all('li')[2].span.text # Combustible
            kilom =vehiculos[element].ul.find_all('li')[3].span.text # Kilómetros
            manual_auto = vehiculos[element].ul.find_all('li')[4].span.text # Cambio
            power = vehiculos[element].ul.find_all('li')[5].span.text # Potencia
            link = vehiculos[element].a['href'] #link

            temp_list.append(model)
            temp_list.append(price)
            temp_list.append(sub_location)
            temp_list.append(year)
            temp_list.append(fuel)
            temp_list.append(kilom)
            temp_list.append(manual_auto)
            temp_list.append(link)
            models_listA.append(temp_list)
        #print(models_listA)
        #print("...............................................................................................")

        #TypeB
        vehiculos = soup.find_all('article',{'class':'anuncio destacado evaluacion'}) 
        models_listB = []
        for element in range(len(vehiculos)):
            temp_list = []
            model =vehiculos[element].a.h2.text #Description
            price =vehiculos[element].a.find_all('p',{'class':'precio'})[0].find_all('span')[0].text
            sub_location = vehiculos[element].ul.find_all('li')[0].span.text # Provincia
            year =vehiculos[element].ul.find_all('li')[1].span.text # Matriculación
            fuel = vehiculos[element].ul.find_all('li')[2].span.text # Combustible
            kilom =vehiculos[element].ul.find_all('li')[3].span.text # Kilómetros
            manual_auto = vehiculos[element].ul.find_all('li')[4].span.text # Cambio
            power = vehiculos[element].ul.find_all('li')[5].span.text # Potencia
            link = vehiculos[element].a['href'] #link

            temp_list.append(model)
            temp_list.append(price)
            temp_list.append(sub_location)
            temp_list.append(year)
            temp_list.append(fuel)
            temp_list.append(kilom)
            temp_list.append(manual_auto)
            temp_list.append(link)
            models_listB.append(temp_list)
        #print(models_listB)
        #print("...............................................................................................")
       
    #TypeC
        vehiculos = soup.find_all('article',{'class':'anuncio destacado'}) 
        models_listC = []
        
        for element in range(len(vehiculos)):
            temp_list = []
            model =vehiculos[element].a.h2.text #Description
            price =vehiculos[element].a.find_all('p',{'class':'precio'})[0].find_all('span')[0].text
            sub_location = vehiculos[element].ul.find_all('li')[0].span.text # Provincia
            year =vehiculos[element].ul.find_all('li')[1].span.text # Matriculación
            fuel = vehiculos[element].ul.find_all('li')[2].span.text # Combustible
            kilom =vehiculos[element].ul.find_all('li')[3].span.text # Kilómetros
            manual_auto = vehiculos[element].ul.find_all('li')[4].span.text # Cambio
            power = vehiculos[element].ul.find_all('li')[5].span.text # Potencia
            link = vehiculos[element].a['href'] #link

            temp_list.append(model)
            temp_list.append(price)
            temp_list.append(sub_location)
            temp_list.append(year)
            temp_list.append(fuel)
            temp_list.append(kilom)
            temp_list.append(manual_auto)
            temp_list.append(link)
            models_listC.append(temp_list)
        #print(models_listC)            
        #print("...............................................................................................")
   
    #TypeD
        vehiculos = soup.find_all('article',{'class':'anuncio'})
        models_listD = []
        
 
        for element in range(len(vehiculos)):
            temp_list = []
            model =vehiculos[element].a.h2.text #Description
            price =vehiculos[element].a.find_all('p',{'class':'precio'})[0].find_all('span')[0].text
            sub_location = vehiculos[element].ul.find_all('li')[0].span.text # Provincia
            year =vehiculos[element].ul.find_all('li')[1].span.text # Matriculación
            fuel = vehiculos[element].ul.find_all('li')[2].span.text # Combustible
            kilom =vehiculos[element].ul.find_all('li')[3].span.text # Kilómetros
            manual_auto = vehiculos[element].ul.find_all('li')[4].span.text # Cambio
            power = vehiculos[element].ul.find_all('li')[5].span.text # Potencia
            link = vehiculos[element].a['href'] #link

            temp_list.append(model)
            temp_list.append(price)
            temp_list.append(sub_location)
            temp_list.append(year)
            temp_list.append(fuel)
            temp_list.append(kilom)
            temp_list.append(manual_auto)
            temp_list.append(link)
            models_listD.append(temp_list)
            
        #print(models_listD)
        #print("...............................................................................................")
        
        main_list.append(models_listA+models_listB+models_listC+models_listD)
        count = count+1
        print(count)
    except:
            pass
        
maindf = pd.DataFrame()
#num = np.random.randint(1,10000000)
for element in main_list:
    dfprov = pd.DataFrame(element)
    maindf = maindf.append(dfprov)
    #maindf.to_csv(f'autocasion_page{num}.csv')
maindf.to_csv('autocasion_unique.csv')
# Out:
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=1
# 1
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=2
# 2
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=3
# 3
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=4
# 4
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=5
# 5
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=6
# 6
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=7
# 7
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=8
# 8
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=9
# 9
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=10
# 10
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=11
# 11
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=12
# 12
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=13
# 13
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=14
# 14
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=15
# 15
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=16
# 16
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=17
# 17
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=18
# 18
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=19
# 19
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=20
# 20
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=21
# 21
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=22
# 22
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=23
# 23
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=24
# 24
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=25
# 25
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=26
# 26
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=27
# 27
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=28
# 28
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=29
# 29
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=30
# 30
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=31
# 31
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=32
# 32
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=33
# 33
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=34
# 34
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=35
# 35
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=36
# 36
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=37
# 37
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=38
# 38
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=39
# 39
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=40
# 40
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=41
# 41
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=42
# 42
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=43
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=44
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=45
# 43
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=46
# 44
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=47
# 45
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=48
# 46
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=49
# 47
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=50
# 48
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=51
# 49
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=52
# 50
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=53
# 51
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=54
# 52
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=55
# 53
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=56
# 54
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=57
# 55
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=58
# 56
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=59
# 57
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=60
# 58
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=61
# 59
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=62
# 60
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=63
# 61
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=64
# 62
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=65
# 63
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=66
# 64
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=67
# 65
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=68
# 66
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=69
# 67
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=70
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=71
# 68
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=72
# 69
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=73
# 70
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page=74
# 71
# https://www.autocasion.com/coches-segunda-mano/fecha-desde-2014/precio-desde-4000/precio-hasta-16000?page
# /coches-segunda-mano/opel-mokka-ocasion/mokka-1-6cdti-s-s-excellence-4x2-ref6992738                  1
# Name: 7, Length: 8868, dtype: int64

# %%
maindf
# Out:
#                                                0          1           2     3  \
# 0          NISSAN Pulsar 1.2 DIG-T 115cv Visia    14.500 €     La Rioja  2018
# 1         NISSAN Qashqai 1.5dCi N-Connecta 4x2    15.500 €     Zaragoza  2016
# 2                FORD Focus 1.5TDCi Trend+ 120    13.900 €    Guipúzcoa  2017
# 3                  PEUGEOT 208 1.6e-HDi Active    11.500 €     Valencia  2014
# 4                          FIAT 500 1.2 Lounge    10.500 €   Pontevedra  2015
# ..                                           ...        ...         ...   ...
# 13       OPEL Mokka 1.6CDTi S&S Excellence 4x2    15.400 €      Granada  2016
# 14       MERCEDES-BENZ Clase A 180CDI BE Urban    14.850 €      Granada  2014
# 15             SEAT Ibiza 1.2 Tsi Reference 85     9.500 €      Granada  2014
# 16    VOLKSWAGEN Polo 5p Edition 1.0 75 CV BMT    11.900 €    Castellón  2015
# 17            PEUGEOT 208 1.0 PureTech Like 68     8.900 €    La Coruña  2014
#
#             4           5           6  \
# 0    Gasolina   86.334 km      Manual
# 1      Diésel  125.000 km      Manual
# 2      Diésel   76.000 km      Manual
# 3      Diésel  118.000 km      Manual
# 4    Gasolina   71.570 km      Manual
# ..        ...         ...         ...
# 13     Diésel  110.935 km  Automático
# 14     Diésel  132.647 km      Manual
# 15   Gasolina   58.511 km      Manual
# 16   Gasolina   48.900 km      Manual
# 17   Gasolina   99.000 km      Manual
#
#                                                     7
# 0   /coches-segunda-mano/nissan-pulsar-ocasion/1-2...
# 1   /coches-segunda-mano/nissan-qashqai-ocasion/qa...
# 2   /coches-segunda-mano/ford-focus-ocasion/focus-...
# 3   /coches-segunda-mano/peugeot-208-ocasion/208-1...
# 4   /coches-segunda-mano/fiat-500-ocasion/500-1-2-...
# ..                                                ...
# 13  /coches-segunda-mano/opel-mokka-ocasion/mokka-...
# 14  /coches-segunda-mano/mercedes-benz-clase-a-oca...
# 15  /coches-segunda-mano/seat-ibiza-ocasion/ibiza-...
# 16  /coches-segunda-mano/volkswagen-polo-ocasion/5...
# 17  /coches-segunda-mano/peugeot-208-ocasion/208-1...
#
# [11912 rows x 8 columns]

# %%
D=pd.DataFrame(models_listD)
D[7].iloc[14]
# Out:
# '/coches-segunda-mano/peugeot-508-ocasion/508-sw-2-0bluehdi-allure-aut-180-ref6980890'

# %%
A=pd.DataFrame(models_listA)
A[7].iloc[6]
# Out:
# '/coches-segunda-mano/peugeot-508-ocasion/508-sw-2-0bluehdi-allure-aut-180-ref6980890'

# %%
pd.DataFrame(models_listB)
# Out:
#                                     0         1        2     3        4  \
# 0    SKODA Rapid 1.4TDI CR Ambition    9.800 €   Vizcaya  2016   Diésel
#
#             5       6                                                  7
# 0  126.000 km  Manual  /coches-segunda-mano/skoda-rapid-ocasion/rapid...

# %%
pd.DataFrame(models_listC)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
